# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv("Best_Movies_Netflix.csv")

# %%
df1
# Out:
#      index                                     TITLE  RELEASE_YEAR  SCORE  \
# 0        0  David Attenborough: A Life on Our Planet          2020    9.0
# 1        1                                 Inception          2010    8.8
# 2        2                              Forrest Gump          1994    8.8
# 3        3                                Anbe Sivam          2003    8.7
# 4        4                        Bo Burnham: Inside          2021    8.7
# ..     ...                                       ...           ...    ...
# 382    382                                  The Trip          2021    6.9
# 383    383                                  The Dirt          2019    6.9
# 384    384                                   Top Gun          1986    6.9
# 385    385                               Radhe Shyam          2022    6.9
# 386    386                       Sorry to Bother You          2018    6.9
#
#      NUMBER_OF_VOTES  DURATION   MAIN_GENRE MAIN_PRODUCTION
# 0              31180        83  documentary              GB
# 1            2268288       148        scifi              GB
# 2            1994599       142        drama              US
# 3              20595       160       comedy              IN
# 4              44074        87       comedy              US
# ..               ...       ...          ...             ...
# 382            19706       113       comedy              NO
# 383            47603       108        drama              US
# 384           329656       110        drama              US
# 385            21328       138      romance              IN
# 386            75653       111      fantasy              US
#
# [387 rows x 8 columns]

# %%
df1.isnull().sum()
# Out:
# index              0
# TITLE              0
# RELEASE_YEAR       0
# SCORE              0
# NUMBER_OF_VOTES    0
# DURATION           0
# MAIN_GENRE         0
# MAIN_PRODUCTION    0
# dtype: int64

# %%
ind_train=df1.iloc[:,2:3]
dep_train=df1.iloc[:,3:6]

# %%
ind_train
# Out:
#      RELEASE_YEAR
# 0            2020
# 1            2010
# 2            1994
# 3            2003
# 4            2021
# ..            ...
# 382          2021
# 383          2019
# 384          1986
# 385          2022
# 386          2018
#
# [387 rows x 1 columns]

# %%
dep_train
# Out:
#      SCORE  NUMBER_OF_VOTES  DURATION
# 0      9.0            31180        83
# 1      8.8          2268288       148
# 2      8.8          1994599       142
# 3      8.7            20595       160
# 4      8.7            44074        87
# ..     ...              ...       ...
# 382    6.9            19706       113
# 383    6.9            47603       108
# 384    6.9           329656       110
# 385    6.9            21328       138
# 386    6.9            75653       111
#
# [387 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(ind_train,dep_train,test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression
lnr=LinearRegression()
lnr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
predicting=lnr.predict(xtest)
predicting
# Out:
# array([[7.43148039e+00, 8.71249146e+04, 1.20915581e+02],
#        [7.51653761e+00, 1.46679191e+05, 1.23228150e+02],
#        [7.67118710e+00, 2.54959693e+05, 1.27432820e+02],
#        [7.51653761e+00, 1.46679191e+05, 1.23228150e+02],
#        [7.42374791e+00, 8.17108895e+04, 1.20705348e+02],
#        [7.43921286e+00, 9.25389397e+04, 1.21125815e+02],
#        [7.60159483e+00, 2.06233467e+05, 1.25540718e+02],
#        [7.46241029e+00, 1.08781015e+05, 1.21756515e+02],
#        [7.47014276e+00, 1.14195040e+05, 1.21966749e+02],
#        [7.47787524e+00, 1.19609065e+05, 1.22176982e+02],
#        [7.50107266e+00, 1.35851141e+05, 1.22807683e+02],
#        [7.56293246e+00, 1.79163341e+05, 1.24489551e+02],
#        [7.48560771e+00, 1.25023090e+05, 1.22387216e+02],
#        [7.60932730e+00, 2.11647492e+05, 1.25750952e+02],
#        [7.43921286e+00, 9.25389397e+04, 1.21125815e+02],
#        [7.45467781e+00, 1.03366990e+05, 1.21546282e+02],
#        [7.42374791e+00, 8.17108895e+04, 1.20705348e+02],
#        [7.65572215e+00, 2.44131643e+05, 1.27012353e+02],
#        [7.46241029e+00, 1.08781015e+05, 1.21756515e+02],
#        [7.43148039e+00, 8.71249146e+04, 1.20915581e+02],
#        [7.55519998e+00, 1.73749316e+05, 1.24279317e+02],
#        [7.44694534e+00, 9.79529648e+04, 1.21336048e+02],
#        [7.43921286e+00, 9.25389397e+04, 1.21125815e+02],
#        [7.50880514e+00, 1.41265166e+05, 1.23017916e+02],
#        [7.60159483e+00, 2.06233467e+05, 1.25540718e+02],
#        [7.45467781e+00, 1.03366990e+05, 1.21546282e+02],
#        [7.49334019e+00, 1.30437115e+05, 1.22597449e+02],
#        [7.51653761e+00, 1.46679191e+05, 1.23228150e+02],
#        [7.48560771e+00, 1.25023090e+05, 1.22387216e+02],
#        [7.53973503e+00, 1.62921266e+05, 1.23858850e+02],
#        [7.47787524e+00, 1.19609065e+05, 1.22176982e+02],
#        [7.43921286e+00, 9.25389397e+04, 1.21125815e+02],
#        [7.52427008e+00, 1.52093216e+05, 1.23438383e+02],
#        [7.42374791e+00, 8.17108895e+04, 1.20705348e+02],
#        [7.44694534e+00, 9.79529648e+04, 1.21336048e+02],
#        [7.50880514e+00, 1.41265166e+05, 1.23017916e+02],
#        [7.43148039e+00, 8.71249146e+04, 1.20915581e+02],
#        [7.44694534e+00, 9.79529648e+04, 1.21336048e+02],
#        [7.47014276e+00, 1.14195040e+05, 1.21966749e+02],
#        [7.56293246e+00, 1.79163341e+05, 1.24489551e+02],
#        [7.42374791e+00, 8.17108895e+04, 1.20705348e+02],
#        [7.43921286e+00, 9.25389397e+04, 1.21125815e+02],
#        [7.53200256e+00, 1.57507241e+05, 1.23648617e+02],
#        [7.49334019e+00, 1.30437115e+05, 1.22597449e+02],
#        [7.53200256e+00, 1.57507241e+05, 1.23648617e+02],
#        [7.50880514e+00, 1.41265166e+05, 1.23017916e+02],
#        [7.42374791e+00, 8.17108895e+04, 1.20705348e+02],
#        [7.53973503e+00, 1.62921266e+05, 1.23858850e+02],
#        [7.45467781e+00, 1.03366990e+05, 1.21546282e+02],
#        [7.45467781e+00, 1.03366990e+05, 1.21546282e+02],
#        [7.43921286e+00, 9.25389397e+04, 1.21125815e+02],
#        [7.45467781e+00, 1.03366990e+05, 1.21546282e+02],
#        [7.42374791e+00, 8.17108895e+04, 1.20705348e+02],
#        [7.41601544e+00, 7.62968644e+04, 1.20495114e+02],
#        [7.43148039e+00, 8.71249146e+04, 1.20915581e+02],
#        [7.64025720e+00, 2.33303592e+05, 1.26591886e+02],
#        [7.55519998e+00, 1.73749316e+05, 1.24279317e+02],
#        [7.86449897e+00, 3.90310320e+05, 1.32688657e+02],
#        [7.45467781e+00, 1.03366990e+05, 1.21546282e+02],
#        [7.49334019e+00, 1.30437115e+05, 1.22597449e+02],
#        [7.48560771e+00, 1.25023090e+05, 1.22387216e+02],
#        [7.43148039e+00, 8.71249146e+04, 1.20915581e+02],
#        [7.81037164e+00, 3.52412145e+05, 1.31217022e+02],
#        [7.43148039e+00, 8.71249146e+04, 1.20915581e+02],
#        [7.45467781e+00, 1.03366990e+05, 1.21546282e+02],
#        [7.47787524e+00, 1.19609065e+05, 1.22176982e+02],
#        [7.43921286e+00, 9.25389397e+04, 1.21125815e+02],
#        [7.45467781e+00, 1.03366990e+05, 1.21546282e+02],
#        [7.47014276e+00, 1.14195040e+05, 1.21966749e+02],
#        [7.50107266e+00, 1.35851141e+05, 1.22807683e+02],
#        [7.88769639e+00, 4.06552396e+05, 1.33319357e+02],
#        [7.45467781e+00, 1.03366990e+05, 1.21546282e+02],
#        [7.50107266e+00, 1.35851141e+05, 1.22807683e+02],
#        [7.50880514e+00, 1.41265166e+05, 1.23017916e+02],
#        [7.53200256e+00, 1.57507241e+05, 1.23648617e+02],
#        [7.43921286e+00, 9.25389397e+04, 1.21125815e+02],
#        [7.52427008e+00, 1.52093216e+05, 1.23438383e+02],
#        [7.55519998e+00, 1.73749316e+05, 1.24279317e+02]])

# %%
xtest
# Out:
#      RELEASE_YEAR
# 179          2020
# 158          2009
# 129          1989
# 225          2009
# 331          2021
# ..            ...
# 286          2010
# 272          2007
# 33           2019
# 165          2008
# 324          2004
#
# [78 rows x 1 columns]

# %%
ytest
# Out:
#      SCORE  NUMBER_OF_VOTES  DURATION
# 179    7.5            14839       165
# 158    7.6            30818       138
# 129    7.7           212913        96
# 225    7.4            17136       135
# 331    7.0            25771       135
# ..     ...              ...       ...
# 286    7.1           120208       116
# 272    7.2           329417       124
# 33     8.1            10649        67
# 165    7.5            32188       213
# 324    7.0            35142       179
#
# [78 rows x 3 columns]

# %%
plt.scatter(xtest,ytest["SCORE"],color='r',label="Year-Wise Score")
plt.plot(xtest,predicting,color='g',linestyle="-")
plt.legend(loc="upper right")
plt.title("Linear Regression")
plt.xlabel("Year")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
plt.scatter(xtest,ytest["NUMBER_OF_VOTES"],color='b',label="Year-Wise Votes")
plt.plot(xtest,predicting,color='g',linestyle="-")
plt.legend(loc="upper right")
plt.title("Linear Regression")
plt.xlabel("Year")
plt.ylabel("Number of Votes")
# Out:
# Text(0, 0.5, 'Number of Votes')

# %%
plt.scatter(xtest,ytest["DURATION"],color='b',label="Year-Wise Duration")
plt.plot(xtest,predicting,color='g',linestyle="-")
plt.legend(loc="upper right")
plt.title("Linear Regression")
plt.xlabel("Year")
plt.ylabel("Duration")
# Out:
# Text(0, 0.5, 'Duration')

# %%
df2=df1=pd.read_csv("Best Shows Netflix.csv")

# %%
df2
# Out:
#      index                       TITLE  RELEASE_YEAR  SCORE  NUMBER_OF_VOTES  \
# 0        0                Breaking Bad          2008    9.5          1727694
# 1        1  Avatar: The Last Airbender          2005    9.3           297336
# 2        2                  Our Planet          2019    9.3            41386
# 3        3                Kota Factory          2019    9.3            66985
# 4        4              The Last Dance          2020    9.1           108321
# ..     ...                         ...           ...    ...              ...
# 241    241                 Evil Genius          2018    7.5            27516
# 242    242              13 Reasons Why          2017    7.5           282373
# 243    243                       Lupin          2021    7.5           100575
# 244    244          All of Us Are Dead          2022    7.5            41393
# 245    245     I Am Not Okay with This          2020    7.5            56459
#
#      DURATION  NUMBER_OF_SEASONS   MAIN_GENRE MAIN_PRODUCTION
# 0          48                  5        drama              US
# 1          24                  3        scifi              US
# 2          50                  1  documentary              GB
# 3          42                  2        drama              IN
# 4          50                  1  documentary              US
# ..        ...                ...          ...             ...
# 241        48                  1        crime              US
# 242        58                  4        drama              US
# 243        46                  3        crime              FR
# 244        61                  1       action              KR
# 245        21                  1       comedy              US
#
# [246 rows x 9 columns]

# %%
df2.isnull().sum()
# Out:
# index                0
# TITLE                0
# RELEASE_YEAR         0
# SCORE                0
# NUMBER_OF_VOTES      0
# DURATION             0
# NUMBER_OF_SEASONS    0
# MAIN_GENRE           0
# MAIN_PRODUCTION      0
# dtype: int64

# %%
ind_train_show=df2.iloc[:,2:3]
dep_train_show=df2.iloc[:,3:7]

# %%
ind_train_show
# Out:
#      RELEASE_YEAR
# 0            2008
# 1            2005
# 2            2019
# 3            2019
# 4            2020
# ..            ...
# 241          2018
# 242          2017
# 243          2021
# 244          2022
# 245          2020
#
# [246 rows x 1 columns]

# %%
dep_train_show
# Out:
#      SCORE  NUMBER_OF_VOTES  DURATION  NUMBER_OF_SEASONS
# 0      9.5          1727694        48                  5
# 1      9.3           297336        24                  3
# 2      9.3            41386        50                  1
# 3      9.3            66985        42                  2
# 4      9.1           108321        50                  1
# ..     ...              ...       ...                ...
# 241    7.5            27516        48                  1
# 242    7.5           282373        58                  4
# 243    7.5           100575        46                  3
# 244    7.5            41393        61                  1
# 245    7.5            56459        21                  1
#
# [246 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(ind_train_show,dep_train_show,test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression
lnr=LinearRegression()
lnr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
predicting2=lnr.predict(xtest)
predicting2
# Out:
# array([[8.11614749e+00, 1.06540490e+05, 4.25509083e+01, 3.60468816e+00],
#        [8.08105531e+00, 9.78705050e+04, 4.35289310e+01, 3.12356657e+00],
#        [8.32670057e+00, 1.58560399e+05, 3.66827718e+01, 6.49141767e+00],
#        [8.15123967e+00, 1.15210475e+05, 4.15728855e+01, 4.08580974e+00],
#        [8.16878576e+00, 1.19545467e+05, 4.10838742e+01, 4.32637053e+00],
#        [8.57234584e+00, 2.19250293e+05, 2.98366125e+01, 9.85926878e+00],
#        [8.01087095e+00, 8.05305352e+04, 4.54849765e+01, 2.16132340e+00],
#        [8.20387794e+00, 1.28215452e+05, 4.01058514e+01, 4.80749212e+00],
#        [8.27406230e+00, 1.45555422e+05, 3.81498059e+01, 5.76973529e+00],
#        [8.06350922e+00, 9.35355125e+04, 4.40179424e+01, 2.88300578e+00],
#        [8.16878576e+00, 1.19545467e+05, 4.10838742e+01, 4.32637053e+00],
#        [8.02841704e+00, 8.48655276e+04, 4.49959652e+01, 2.40188419e+00],
#        [8.01087095e+00, 8.05305352e+04, 4.54849765e+01, 2.16132340e+00],
#        [8.06350922e+00, 9.35355125e+04, 4.40179424e+01, 2.88300578e+00],
#        [8.18633185e+00, 1.23880460e+05, 4.05948628e+01, 4.56693133e+00],
#        [8.08105531e+00, 9.78705050e+04, 4.35289310e+01, 3.12356657e+00],
#        [8.11614749e+00, 1.06540490e+05, 4.25509083e+01, 3.60468816e+00],
#        [8.11614749e+00, 1.06540490e+05, 4.25509083e+01, 3.60468816e+00],
#        [8.29160839e+00, 1.49890414e+05, 3.76607945e+01, 6.01029609e+00],
#        [8.11614749e+00, 1.06540490e+05, 4.25509083e+01, 3.60468816e+00],
#        [8.08105531e+00, 9.78705050e+04, 4.35289310e+01, 3.12356657e+00],
#        [8.01087095e+00, 8.05305352e+04, 4.54849765e+01, 2.16132340e+00],
#        [8.02841704e+00, 8.48655276e+04, 4.49959652e+01, 2.40188419e+00],
#        [8.04596313e+00, 8.92005201e+04, 4.45069538e+01, 2.64244498e+00],
#        [8.11614749e+00, 1.06540490e+05, 4.25509083e+01, 3.60468816e+00],
#        [8.08105531e+00, 9.78705050e+04, 4.35289310e+01, 3.12356657e+00],
#        [8.50216147e+00, 2.01910324e+05, 3.17926580e+01, 8.89702560e+00],
#        [8.18633185e+00, 1.23880460e+05, 4.05948628e+01, 4.56693133e+00],
#        [8.37933884e+00, 1.71565377e+05, 3.52157376e+01, 7.21310005e+00],
#        [8.22142403e+00, 1.32550445e+05, 3.96168400e+01, 5.04805291e+00],
#        [8.13369358e+00, 1.10875482e+05, 4.20618969e+01, 3.84524895e+00],
#        [8.04596313e+00, 8.92005201e+04, 4.45069538e+01, 2.64244498e+00],
#        [8.11614749e+00, 1.06540490e+05, 4.25509083e+01, 3.60468816e+00],
#        [8.09860140e+00, 1.02205497e+05, 4.30399197e+01, 3.36412736e+00],
#        [8.20387794e+00, 1.28215452e+05, 4.01058514e+01, 4.80749212e+00],
#        [8.01087095e+00, 8.05305352e+04, 4.54849765e+01, 2.16132340e+00],
#        [8.08105531e+00, 9.78705050e+04, 4.35289310e+01, 3.12356657e+00],
#        [8.06350922e+00, 9.35355125e+04, 4.40179424e+01, 2.88300578e+00],
#        [8.04596313e+00, 8.92005201e+04, 4.45069538e+01, 2.64244498e+00],
#        [8.37933884e+00, 1.71565377e+05, 3.52157376e+01, 7.21310005e+00],
#        [8.09860140e+00, 1.02205497e+05, 4.30399197e+01, 3.36412736e+00],
#        [8.18633185e+00, 1.23880460e+05, 4.05948628e+01, 4.56693133e+00],
#        [8.02841704e+00, 8.48655276e+04, 4.49959652e+01, 2.40188419e+00],
#        [8.08105531e+00, 9.78705050e+04, 4.35289310e+01, 3.12356657e+00],
#        [8.15123967e+00, 1.15210475e+05, 4.15728855e+01, 4.08580974e+00],
#        [8.06350922e+00, 9.35355125e+04, 4.40179424e+01, 2.88300578e+00],
#        [8.02841704e+00, 8.48655276e+04, 4.49959652e+01, 2.40188419e+00],
#        [8.08105531e+00, 9.78705050e+04, 4.35289310e+01, 3.12356657e+00],
#        [8.08105531e+00, 9.78705050e+04, 4.35289310e+01, 3.12356657e+00],
#        [8.02841704e+00, 8.48655276e+04, 4.49959652e+01, 2.40188419e+00]])

# %%
xtest
# Out:
#      RELEASE_YEAR
# 207          2015
# 164          2017
# 15           2003
# 138          2013
# 147          2012
# 9            1989
# 126          2021
# 179          2010
# 84           2006
# 70           2018
# 64           2012
# 37           2020
# 182          2021
# 93           2018
# 101          2011
# 171          2017
# 232          2015
# 140          2015
# 50           2005
# 25           2015
# 210          2017
# 66           2021
# 219          2020
# 122          2019
# 193          2015
# 51           2017
# 116          1993
# 169          2011
# 142          2000
# 43           2009
# 129          2014
# 228          2019
# 157          2015
# 137          2016
# 55           2010
# 195          2021
# 184          2017
# 212          2018
# 162          2019
# 99           2000
# 237          2016
# 39           2011
# 229          2020
# 82           2017
# 131          2013
# 108          2018
# 234          2020
# 161          2017
# 156          2017
# 245          2020

# %%
ytest
# Out:
#      SCORE  NUMBER_OF_VOTES  DURATION  NUMBER_OF_SEASONS
# 207    7.6            24142        41                  8
# 164    7.8            13238        43                  2
# 15     8.8            62140        21                  3
# 138    7.9            13372        25                  1
# 147    7.9            29196        45                  3
# 9      8.9           302700        24                  9
# 126    8.0           416738        54                  2
# 179    7.7            13848        26                  1
# 84     8.3           121514        25                  7
# 70     8.4            19940        25                  1
# 64     8.4           117464        23                  4
# 37     8.6            21104        76                  1
# 182    7.7           102321        64                  1
# 93     8.2            38232        26                  3
# 101    8.2            12568        25                  2
# 171    7.8            17992        44                  3
# 232    7.5            41867        43                  3
# 140    7.9            45628        43                  3
# 50     8.5           428639        45                 15
# 25     8.7           148386        24                  2
# 210    7.6            13855        50                  5
# 66     8.4            15134        81                  1
# 219    7.5            13797        46                  2
# 122    8.0           202522        52                  3
# 193    7.7            10102        22                  4
# 51     8.5           278223        60                  4
# 116    8.1            61145        47                  7
# 169    7.8            37778        21                  3
# 142    7.9            15823        25                  9
# 43     8.5           252564        23                  6
# 129    8.0            71229        55                  2
# 228    7.5            21887        43                  2
# 157    7.9            16273        54                  3
# 137    7.9            28537        42                  5
# 55     8.5            23523        58                  4
# 195    7.6            15137        28                  1
# 184    7.7            31577        44                  1
# 212    7.6            18575        25                  1
# 162    7.8            88945        28                  2
# 99     8.2           119054        46                  8
# 237    7.5            88019        44                  3
# 39     8.6           230243        54                 11
# 229    7.5            36185        47                  2
# 82     8.3            81643        31                  4
# 131    8.0           238138        43                  9
# 108    8.1            29298        67                  1
# 234    7.5            16978        25                  1
# 161    7.8            14892        22                  6
# 156    7.9            74660        27                  6
# 245    7.5            56459        21                  1

# %%
plt.scatter(xtest,ytest["SCORE"],color='r',label="Year-Wise Score of Shows")
plt.plot(xtest,predicting2,color='g',linestyle="-")
plt.legend(loc="upper right")
plt.title("Linear Regression")
plt.xlabel("Year")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
plt.scatter(xtest,ytest["NUMBER_OF_VOTES"],color='r',label="Year-Wise Votes for Shows")
plt.plot(xtest,predicting2,color='g',linestyle="-")
plt.legend(loc="upper right")
plt.title("Linear Regression")
plt.xlabel("Year")
plt.ylabel("Votes")
# Out:
# Text(0, 0.5, 'Votes')

# %%
plt.scatter(xtest,ytest["DURATION"],color='r',label="Year-Wise Duration of Shows")
plt.plot(xtest,predicting2,color='g',linestyle="-")
plt.legend(loc="upper right")
plt.title("Linear Regression")
plt.xlabel("Year")
plt.ylabel("Duration")
# Out:
# Text(0, 0.5, 'Duration')

# %%
plt.scatter(xtest,ytest["NUMBER_OF_SEASONS"],color='r',label="Year-Wise Seasons of Shows")
plt.plot(xtest,predicting2,color='g',linestyle="-")
plt.legend(loc="upper right")
plt.title("Linear Regression")
plt.xlabel("Year")
plt.ylabel("No. of Seasons")
# Out:
# Text(0, 0.5, 'No. of Seasons')
